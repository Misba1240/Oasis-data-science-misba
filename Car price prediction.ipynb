# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/91992/Downloads/archive/car data.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
#columns in the data set
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
print("The first Five values of the data set :\n")
df.head()
# Out:
# The first Five values of the data set :
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
print("The Last Five values of the data set :\n")
df.tail()
# Out:
# The Last Five values of the data set :
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Selling_type Transmission  Owner
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0

# %%
#information about the data set
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
#checking for null values
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
#STATISTICS ABOUT THE DATA
print("The Statistics of the data:\n")
df.describe()
# Out:
# The Statistics of the data:
#               Year  Selling_Price  Present_Price     Driven_kms       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.642584   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
# shape and size of dataset
print("The Dimensions of the dataset:",df.shape)
print("The Number of values of the dataset:",df.size)
# Out:
# The Dimensions of the dataset: (301, 9)
# The Number of values of the dataset: 2709

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
# CHECKING FOR CATEGORICAL DISTRIBUTION OF THE DATA
#there are 9 catageries
print("1.FUELTYPE:\n")
print(df['Fuel_Type'].value_counts())
print("\n")
print("3.SELLING TYPE:\n")
print(df['Selling_type'].value_counts())
print("\n")
print("4.TRANSMISSION:\n")
print(df['Transmission'].value_counts())
print("\n")
print("5.OWNER:\n")
print(df['Owner'].value_counts())
print("\n")
print("6.DRIVEN KILOMETER:\n")
print(df['Driven_kms'].value_counts())
print("\n")
print("7.PRESENT PRICE:\n")
print(df['Present_Price'].value_counts())
print("\n")
print("8.SELLING PRICE:\n")
print(df['Selling_Price'].value_counts())
print("\n")
print("9.YEAR:\n")
print(df['Year'].value_counts())
# Out:
# 1.FUELTYPE:
#
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64
#
#
# 3.SELLING TYPE:
#
# Selling_type
# Dealer        195
# Individual    106
# Name: count, dtype: int64
#
#
# 4.TRANSMISSION:
#
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64
#
#
# 5.OWNER:
#
# Owner
# 0    290
# 1     10
# 3      1
# Name: count, dtype: int64
#
#
# 6.DRIVEN KILOMETER:
#
# Driven_kms
# 45000    9
# 15000    9
# 40000    5
# 35000    5
# 50000    5
#         ..
# 1400     1
# 1200     1
# 4100     1
# 21700    1
# 5464     1
# Name: count, Length: 206, dtype: int64
#
#
# 7.PRESENT PRICE:
#
# Present_Price
# 9.40     14
# 13.60    13
# 5.70      8
# 1.47      7
# 0.51      6
#          ..
# 36.23     1
# 18.54     1
# 7.27      1
# 15.04     1
# 12.50     1
# Name: count, Length: 148, dtype: int64
#
#
# 8.SELLING PRICE:
#
# Selling_Price
# 0.45     8
# 0.60     8
# 5.25     7
# 4.50     7
# 0.20     6
#         ..
# 3.80     1
# 3.45     1
# 5.90     1
# 35.00    1
# 11.50    1
# Name: count, Length: 156, dtype: int64
#
#
# 9.YEAR:
#
# Year
# 2015    61
# 2016    50
# 2014    38
# 2017    35
# 2013    33
# 2012    23
# 2011    19
# 2010    15
# 2008     7
# 2009     6
# 2006     4
# 2005     4
# 2003     2
# 2007     2
# 2018     1
# 2004     1
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
car = ['Car_Name','Year','Selling_Price','Present_Price','Driven_kms','Fuel_Type','Selling_type','Transmission','Owner']
for var in car:
    label_encoder = LabelEncoder()
    df[var+'_label_encoded'] = label_encoder.fit_transform(df[var])
df.drop(car,axis=1,inplace = True)
print("The encoded data\n:")
df
# Out:
# The encoded data
# :
#      Car_Name_label_encoded  Year_label_encoded  Selling_Price_label_encoded  \
# 0                        90                  11                           59
# 1                        93                  10                           78
# 2                        68                  14                          112
# 3                        96                   8                           52
# 4                        92                  11                           76
# ..                      ...                 ...                          ...
# 296                      69                  13                          129
# 297                      66                  12                           70
# 298                      69                   6                           59
# 299                      69                  14                          137
# 300                      66                  13                           88
#
#      Present_Price_label_encoded  Driven_kms_label_encoded  \
# 0                             58                        86
# 1                            105                       135
# 2                            107                        26
# 3                             49                        18
# 4                             74                       134
# ..                           ...                       ...
# 296                          116                       103
# 297                           63                       172
# 298                          115                       193
# 299                          121                        31
# 300                           63                        20
#
#      Fuel_Type_label_encoded  Selling_type_label_encoded  \
# 0                          2                           0
# 1                          1                           0
# 2                          2                           0
# 3                          2                           0
# 4                          1                           0
# ..                       ...                         ...
# 296                        1                           0
# 297                        2                           0
# 298                        2                           0
# 299                        1                           0
# 300                        2                           0
#
#      Transmission_label_encoded  Owner_label_encoded
# 0                             1                    0
# 1                             1                    0
# 2                             1                    0
# 3                             1                    0
# 4                             1                    0
# ..                          ...                  ...
# 296                           1                    0
# 297                           1                    0
# 298                           1                    0
# 299                           1                    0
# 300                           1                    0
#
# [301 rows x 9 columns]

# %%
df.corr(numeric_only = True)
# Out:
#                              Car_Name_label_encoded  Year_label_encoded  \
# Car_Name_label_encoded                     1.000000            0.017265
# Year_label_encoded                         0.017265            1.000000
# Selling_Price_label_encoded                0.681559            0.303228
# Present_Price_label_encoded                0.699060           -0.006486
# Driven_kms_label_encoded                   0.296126           -0.606800
# Fuel_Type_label_encoded                   -0.371446           -0.053643
# Selling_type_label_encoded                -0.829718           -0.039896
# Transmission_label_encoded                -0.059855            0.000394
# Owner_label_encoded                       -0.097531           -0.171232
#
#                              Selling_Price_label_encoded  \
# Car_Name_label_encoded                          0.681559
# Year_label_encoded                              0.303228
# Selling_Price_label_encoded                     1.000000
# Present_Price_label_encoded                     0.904882
# Driven_kms_label_encoded                        0.147950
# Fuel_Type_label_encoded                        -0.494877
# Selling_type_label_encoded                     -0.767899
# Transmission_label_encoded                     -0.230202
# Owner_label_encoded                            -0.126217
#
#                              Present_Price_label_encoded  \
# Car_Name_label_encoded                          0.699060
# Year_label_encoded                             -0.006486
# Selling_Price_label_encoded                     0.904882
# Present_Price_label_encoded                     1.000000
# Driven_kms_label_encoded                        0.382519
# Fuel_Type_label_encoded                        -0.460583
# Selling_type_label_encoded                     -0.777158
# Transmission_label_encoded                     -0.233969
# Owner_label_encoded                            -0.063002
#
#                              Driven_kms_label_encoded  \
# Car_Name_label_encoded                       0.296126
# Year_label_encoded                          -0.606800
# Selling_Price_label_encoded                  0.147950
# Present_Price_label_encoded                  0.382519
# Driven_kms_label_encoded                     1.000000
# Fuel_Type_label_encoded                     -0.306820
# Selling_type_label_encoded                  -0.331984
# Transmission_label_encoded                  -0.029118
# Owner_label_encoded                          0.047534
#
#                              Fuel_Type_label_encoded  \
# Car_Name_label_encoded                     -0.371446
# Year_label_encoded                         -0.053643
# Selling_Price_label_encoded                -0.494877
# Present_Price_label_encoded                -0.460583
# Driven_kms_label_encoded                   -0.306820
# Fuel_Type_label_encoded                     1.000000
# Selling_type_label_encoded                  0.352415
# Transmission_label_encoded                  0.080466
# Owner_label_encoded                         0.057210
#
#                              Selling_type_label_encoded  \
# Car_Name_label_encoded                        -0.829718
# Year_label_encoded                            -0.039896
# Selling_Price_label_encoded                   -0.767899
# Present_Price_label_encoded                   -0.777158
# Driven_kms_label_encoded                      -0.331984
# Fuel_Type_label_encoded                        0.352415
# Selling_type_label_encoded                     1.000000
# Transmission_label_encoded                     0.063240
# Owner_label_encoded                            0.123854
#
#                              Transmission_label_encoded  Owner_label_encoded
# Car_Name_label_encoded                        -0.059855            -0.097531
# Year_label_encoded                             0.000394            -0.171232
# Selling_Price_label_encoded                   -0.230202            -0.126217
# Present_Price_label_encoded                   -0.233969            -0.063002
# Driven_kms_label_encoded                      -0.029118             0.047534
# Fuel_Type_label_encoded                        0.080466             0.057210
# Selling_type_label_encoded                     0.063240             0.123854
# Transmission_label_encoded                     1.000000            -0.018716
# Owner_label_encoded                           -0.018716             1.000000

# %%
plot = plt.figure(figsize =(20,20))
plot = sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm')
plt.title('CORELATION MATRIX')
plt.show()

# %%
df
# Out:
#      Car_Name_label_encoded  Year_label_encoded  Selling_Price_label_encoded  \
# 0                        90                  11                           59
# 1                        93                  10                           78
# 2                        68                  14                          112
# 3                        96                   8                           52
# 4                        92                  11                           76
# ..                      ...                 ...                          ...
# 296                      69                  13                          129
# 297                      66                  12                           70
# 298                      69                   6                           59
# 299                      69                  14                          137
# 300                      66                  13                           88
#
#      Present_Price_label_encoded  Driven_kms_label_encoded  \
# 0                             58                        86
# 1                            105                       135
# 2                            107                        26
# 3                             49                        18
# 4                             74                       134
# ..                           ...                       ...
# 296                          116                       103
# 297                           63                       172
# 298                          115                       193
# 299                          121                        31
# 300                           63                        20
#
#      Fuel_Type_label_encoded  Selling_type_label_encoded  \
# 0                          2                           0
# 1                          1                           0
# 2                          2                           0
# 3                          2                           0
# 4                          1                           0
# ..                       ...                         ...
# 296                        1                           0
# 297                        2                           0
# 298                        2                           0
# 299                        1                           0
# 300                        2                           0
#
#      Transmission_label_encoded  Owner_label_encoded
# 0                             1                    0
# 1                             1                    0
# 2                             1                    0
# 3                             1                    0
# 4                             1                    0
# ..                          ...                  ...
# 296                           1                    0
# 297                           1                    0
# 298                           1                    0
# 299                           1                    0
# 300                           1                    0
#
# [301 rows x 9 columns]

# %%
#we must drop the price because we have to predict it
x = df.drop(columns =['Selling_Price_label_encoded','Car_Name_label_encoded'],axis=1)
y = df['Selling_Price_label_encoded']

# %%
df.columns
# Out:
# Index(['Car_Name_label_encoded', 'Year_label_encoded',
#        'Selling_Price_label_encoded', 'Present_Price_label_encoded',
#        'Driven_kms_label_encoded', 'Fuel_Type_label_encoded',
#        'Selling_type_label_encoded', 'Transmission_label_encoded',
#        'Owner_label_encoded'],
#       dtype='object')

# %%
print('The prices data:\n')
y
# Out:
# The prices data:
# 0       59
# 1       78
# 2      112
# 3       52
# 4       76
#       ...
# 296    129
# 297     70
# 298     59
# 299    137
# 300     88
# Name: Selling_Price_label_encoded, Length: 301, dtype: int64

# %%
#splitting the data
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
print("The x data:\n")
x
# Out:
# The x data:
#      Year_label_encoded  Present_Price_label_encoded  \
# 0                    11                           58
# 1                    10                          105
# 2                    14                          107
# 3                     8                           49
# 4                    11                           74
# ..                  ...                          ...
# 296                  13                          116
# 297                  12                           63
# 298                   6                          115
# 299                  14                          121
# 300                  13                           63
#
#      Driven_kms_label_encoded  Fuel_Type_label_encoded  \
# 0                          86                        2
# 1                         135                        1
# 2                          26                        2
# 3                          18                        2
# 4                         134                        1
# ..                        ...                      ...
# 296                       103                        1
# 297                       172                        2
# 298                       193                        2
# 299                        31                        1
# 300                        20                        2
#
#      Selling_type_label_encoded  Transmission_label_encoded  \
# 0                             0                           1
# 1                             0                           1
# 2                             0                           1
# 3                             0                           1
# 4                             0                           1
# ..                          ...                         ...
# 296                           0                           1
# 297                           0                           1
# 298                           0                           1
# 299                           0                           1
# 300                           0                           1
#
#      Owner_label_encoded
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ..                   ...
# 296                    0
# 297                    0
# 298                    0
# 299                    0
# 300                    0
#
# [301 rows x 7 columns]

# %%
print("TRAINING DATA")
print("X_train")
display(X_train)
print("Y_train")
display(Y_train)
# Out:
# TRAINING DATA
# X_train
#      Year_label_encoded  Present_Price_label_encoded  \
# 102                  14                           36
# 80                   13                          130
# 245                   9                          104
# 163                   7                           25
# 131                  12                           18
# ..                  ...                          ...
# 203                   8                           52
# 255                   9                           56
# 72                   10                          134
# 235                  14                          104
# 37                    0                           39
#
#      Driven_kms_label_encoded  Fuel_Type_label_encoded  \
# 102                        13                        2
# 80                         76                        1
# 245                       185                        1
# 163                        86                        2
# 131                        60                        2
# ..                        ...                      ...
# 203                       158                        2
# 255                       159                        2
# 72                        165                        2
# 235                        52                        2
# 37                        199                        2
#
#      Selling_type_label_encoded  Transmission_label_encoded  \
# 102                           1                           1
# 80                            0                           1
# 245                           0                           1
# 163                           1                           1
# 131                           1                           1
# ..                          ...                         ...
# 203                           0                           1
# 255                           0                           1
# 72                            0                           1
# 235                           0                           1
# 37                            1                           1
#
#      Owner_label_encoded
# 102                    0
# 80                     0
# 245                    0
# 163                    0
# 131                    0
# ..                   ...
# 203                    0
# 255                    0
# 72                     0
# 235                    0
# 37                     0
#
# [240 rows x 7 columns]
# Y_train
# 102     39
# 80     143
# 245     86
# 163     15
# 131     24
#       ...
# 203     54
# 255     55
# 72     114
# 235    126
# 37      11
# Name: Selling_Price_label_encoded, Length: 240, dtype: int64

# %%
print("TESTING DATA")
print("X_test")
display(X_test)
print("Y_test")
display(Y_test)
# Out:
# TESTING DATA
# X_test
#      Year_label_encoded  Present_Price_label_encoded  \
# 285                  13                           97
# 248                  10                           52
# 150                   8                           19
# 217                  13                           51
# 107                  10                           33
# ..                  ...                          ...
# 62                   11                          145
# 154                  11                           23
# 218                  11                           96
# 286                  13                           90
# 186                   7                            4
#
#      Driven_kms_label_encoded  Fuel_Type_label_encoded  \
# 285                        51                        2
# 248                        93                        2
# 150                        24                        2
# 217                        49                        2
# 107                        49                        2
# ..                        ...                      ...
# 62                        190                        1
# 154                        28                        2
# 218                       140                        2
# 286                        90                        2
# 186                        73                        2
#
#      Selling_type_label_encoded  Transmission_label_encoded  \
# 285                           0                           0
# 248                           0                           1
# 150                           1                           1
# 217                           0                           1
# 107                           1                           1
# ..                          ...                         ...
# 62                            0                           0
# 154                           1                           1
# 218                           0                           1
# 286                           0                           1
# 186                           1                           0
#
#      Owner_label_encoded
# 285                    0
# 248                    0
# 150                    0
# 217                    0
# 107                    0
# ..                   ...
# 62                     0
# 154                    0
# 218                    0
# 286                    0
# 186                    0
#
# [61 rows x 7 columns]
# Y_test
# 285    113
# 248     70
# 150     17
# 217     57
# 107     35
#       ...
# 62     148
# 154     17
# 218    103
# 286     92
# 186      7
# Name: Selling_Price_label_encoded, Length: 61, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model1 = LinearRegression()

# %%
model1.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
#training set prediction
training_data_prediction = model1.predict(X_train)

# %%
from sklearn import metrics
from sklearn.metrics import r2_score

# %%
error_score = metrics.r2_score(Y_train,training_data_prediction)
print("R squared error :",error_score)
# Out:
# R squared error : 0.9321936168293049

# %%
plt.scatter(Y_train,training_data_prediction,color = 'green')
plt.xlabel('Actual Price')
plt.ylabel('predictied Price')
plt.title("Actual price V/s Predicted price")
plt.show()

# %%
#for the test data predidctions
test_data_prediction = model1.predict(X_test)

# %%
#R square error
error_square = metrics.r2_score(Y_test,test_data_prediction)
print('R square Error:',error_score)
# Out:
# R square Error: 0.9321936168293049

# %%
#visualization of test
plt.scatter(Y_test,test_data_prediction,)
plt.xlabel('Actual Price')
plt.ylabel('predictied Price')
plt.title("Actual price V/s Predicted price")
plt.show()

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score

# %%
model2 = Lasso()

# %%
#training
model2.fit(X_train,Y_train)
training_data_predictions = model2.predict(X_train)
error_score = metrics.r2_score(Y_train,training_data_predictions)
print("Error_score",error_score)
# Out:
# Error_score 0.9197161668178598

# %%
#visualisation
plt.scatter(Y_train,training_data_predictions)
plt.xlabel('Actual Price')
plt.ylabel('Predicted price')
plt.show()

# %%
#testing data
model2.fit(X_train,Y_train)
test_data_predictions = model2.predict(X_test)
error_score = metrics.r2_score(Y_test,test_data_predictions)
print("Error_score",error_score)
# Out:
# Error_score 0.9000470006332426

# %%
plt.scatter(Y_test,test_data_predictions)
plt.xlabel('Actual price')
plt.ylabel('Predicted Price')
plt.title("CAR PRICE PREDICTION")
plt.show()
